# %%
import gym

class ActionSamplingEnvironment:
    def __init__(self, env: gym.Env):
        self._env = env

    @property
    def metadata(self):
        return self._env.metadata
    
    @property
    def reward_range(self):
        return self._env.reward_range
    
    @property
    def spec(self):
        return self._env.spec

    @property
    def action_space(self):
        return self._env.action_space

    @property
    def observation_space(self):
        return self._env.observation_space

    def step(self, action_dist):
        """Run one timestep of the environment's dynamics. When end of
        episode is reached, you are responsible for calling `reset()`
        to reset this environment's state.

        Accepts an action and returns a tuple (observation, reward, done, info).

        Args:
            action_dist (object): a distribution over actions, provided by the agent

        Returns:
            action (object): an action sampled from the provided distribution
            observation (object): agent's observation of the current environment
            reward (float) : amount of reward returned after previous action
            done (bool): whether the episode has ended, in which case further step() calls will return undefined results
            info (dict): contains auxiliary diagnostic information (helpful for debugging, and sometimes learning)
        """
        action = action_dist.sample()
        next_obs, reward, done, info = self._env.step(action.numpy())
        return action, next_obs, reward, done, info

    def reset(self):
        """Resets the state of the environment and returns an initial observation.

        Returns:
            observation (object): the initial observation.
        """
        return self._env.reset()

    def render(self, mode='human'):
        self._env.render(mode=mode)

    def close(self):
        """Override close in your subclass to perform any necessary cleanup.

        Environments will automatically close() themselves when
        garbage collected or when the program exits.
        """
        self._env.close()

    def seed(self, seed=None):
        """Sets the seed for this env's random number generator(s).

        Note:
            Some environments use multiple pseudorandom number generators.
            We want to capture all such seeds used in order to ensure that
            there aren't accidental correlations between multiple generators.

        Returns:
            list<bigint>: Returns the list of seeds used in this env's random
              number generators. The first value in the list should be the
              "main" seed, or the value which a reproducer should pass to
              'seed'. Often, the main seed equals the provided 'seed', but
              this won't be true if seed=None, for example.
        """
        return self._env.seed(seed=seed)

    @property
    def unwrapped(self):
        """Completely unwrap this env.

        Returns:
            gym.Env: The base non-wrapped gym.Env instance
        """
        return self._env.unwrapped

    def __str__(self):
        return self._env.__str__()

    def __enter__(self):
        """Support with-statement for the environment. """
        return self._env.__enter__()

    def __exit__(self, *args):
        """Support with-statement for the environment. """
        return self._env.__exit__(*args)

# %%
try:
    import cPickle as pickle
except:
    import pickle


class EnvironmentRecorder(ActionSamplingEnvironment):
    def __init__(self, env: gym.Env, experience_path):
        super().__init__(env)
        self._experience_path = experience_path
        self._fout = open(experience_path, 'wb')
        self._pickler = pickle.Pickler(self._fout)
        self._obs = None
    
    def reset(self):
        self._obs = super().reset()
        return self._obs
    
    def step(self, action_dist):
        action, next_obs, reward, done, info = super().step(action_dist)
        self._pickler.dump((self._obs, action_dist, action, reward, next_obs, done))
        self._obs = next_obs
        return action, next_obs, reward, done, info

# %%
from spinup import ppo_pytorch as ppo
import torch
import gym

env_fn = lambda : EnvironmentRecorder(gym.make('CartPole-v1'), 'cartpole_ppo_learner.pkl')

ac_kwargs = dict(hidden_sizes=[32,32], activation=torch.nn.ReLU)

logger_kwargs = dict(output_dir='cartpole', exp_name='cartpole_ppo_learner')

ppo(env_fn=env_fn, ac_kwargs=ac_kwargs, steps_per_epoch=500, epochs=100, logger_kwargs=logger_kwargs)
# Out:
# Logging data to cartpole/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             32,
#             32
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "clip_ratio":	0.2,
#     "env_fn":	"<function <lambda> at 0x7f6a0443e0d0>",
#     "epochs":	100,
#     "exp_name":	"cartpole_ppo_learner",
#     "gamma":	0.99,
#     "lam":	0.97,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f69d384d5c0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"cartpole_ppo_learner",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"cartpole",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='cartpole/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"cartpole_ppo_learner",
#         "output_dir":	"cartpole"
#     },
#     "max_ep_len":	1000,
#     "pi_lr":	0.0003,
#     "save_freq":	10,
#     "seed":	0,
#     "steps_per_epoch":	500,
#     "target_kl":	0.01,
#     "train_pi_iters":	80,
#     "train_v_iters":	80,
#     "vf_lr":	0.001
# }
#
# Number of parameters: 	 pi: 1282, 	 v: 1249
# /home/sebastko/miniconda3/envs/spinninguprr/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Warning: trajectory cut off by epoch at 13 steps.
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |               0 |
# |      AverageEpRet |            23.2 |
# |          StdEpRet |            12.2 |
# |          MaxEpRet |              57 |
# |          MinEpRet |               9 |
# |             EpLen |            23.2 |
# |      AverageVVals |          0.0356 |
# |          StdVVals |          0.0271 |
# |          MaxVVals |           0.108 |
# |          MinVVals |         -0.0608 |
# | TotalEnvInteracts |             500 |
# |            LossPi |          0.0178 |
# |             LossV |             273 |
# |       DeltaLossPi |         -0.0398 |
# |        DeltaLossV |           -41.3 |
# |           Entropy |            0.68 |
# |                KL |          0.0132 |
# |          ClipFrac |            0.29 |
# |          StopIter |              79 |
# |              Time |            1.63 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 28 steps.
# Early stopping at step 57 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            23.6 |
# |          StdEpRet |            14.8 |
# |          MaxEpRet |              69 |
# |          MinEpRet |               9 |
# |             EpLen |            23.6 |
# |      AverageVVals |            1.93 |
# |          StdVVals |           0.567 |
# |          MaxVVals |            4.71 |
# |          MinVVals |            1.38 |
# | TotalEnvInteracts |           1e+03 |
# |            LossPi |        -0.00445 |
# |             LossV |             295 |
# |       DeltaLossPi |          -0.016 |
# |        DeltaLossV |            -111 |
# |           Entropy |           0.691 |
# |                KL |           0.015 |
# |          ClipFrac |           0.044 |
# |          StopIter |              57 |
# |              Time |            3.35 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 2 steps.
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            31.1 |
# |          StdEpRet |            13.7 |
# |          MaxEpRet |              62 |
# |          MinEpRet |              12 |
# |             EpLen |            31.1 |
# |      AverageVVals |             8.6 |
# |          StdVVals |               2 |
# |          MaxVVals |            18.9 |
# |          MinVVals |             6.1 |
# | TotalEnvInteracts |         1.5e+03 |
# |            LossPi |        0.000763 |
# |             LossV |             198 |
# |       DeltaLossPi |         -0.0084 |
# |        DeltaLossV |             -79 |
# |           Entropy |            0.69 |
# |                KL |        0.000646 |
# |          ClipFrac |           0.036 |
# |          StopIter |              79 |
# |              Time |            4.56 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 4 steps.
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            19.8 |
# |          StdEpRet |            9.04 |
# |          MaxEpRet |              40 |
# |          MinEpRet |               8 |
# |             EpLen |            19.8 |
# |      AverageVVals |            16.2 |
# |          StdVVals |            2.94 |
# |          MaxVVals |            28.8 |
# |          MinVVals |            12.9 |
# | TotalEnvInteracts |           2e+03 |
# |            LossPi |        -0.00915 |
# |             LossV |             104 |
# |       DeltaLossPi |         -0.0126 |
# |        DeltaLossV |           -61.6 |
# |           Entropy |           0.691 |
# |                KL |          0.0144 |
# |          ClipFrac |           0.246 |
# |          StopIter |              79 |
# |              Time |            5.87 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 51 steps.
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            32.1 |
# |          StdEpRet |            14.3 |
# |          MaxEpRet |              71 |
# |          MinEpRet |              16 |
# |             EpLen |            32.1 |
# |      AverageVVals |            11.4 |
# |          StdVVals |             1.7 |
# |          MaxVVals |            15.1 |
# |          MinVVals |            5.03 |
# | TotalEnvInteracts |         2.5e+03 |
# |            LossPi |        -0.00587 |
# |             LossV |             176 |
# |       DeltaLossPi |        -0.00655 |
# |        DeltaLossV |           -62.4 |
# |           Entropy |           0.687 |
# |                KL |        -0.00624 |
# |          ClipFrac |           0.194 |
# |          StopIter |              79 |
# |              Time |            7.07 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 25 steps.
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            31.7 |
# |          StdEpRet |            20.7 |
# |          MaxEpRet |              70 |
# |          MinEpRet |               8 |
# |             EpLen |            31.7 |
# |      AverageVVals |              17 |
# |          StdVVals |            3.62 |
# |          MaxVVals |            21.5 |
# |          MinVVals |            1.32 |
# | TotalEnvInteracts |           3e+03 |
# |            LossPi |         -0.0118 |
# |             LossV |             155 |
# |       DeltaLossPi |         -0.0112 |
# |        DeltaLossV |           -26.8 |
# |           Entropy |           0.687 |
# |                KL |         0.00388 |
# |          ClipFrac |           0.256 |
# |          StopIter |              79 |
# |              Time |            8.27 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 32 steps.
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |              26 |
# |          StdEpRet |            13.1 |
# |          MaxEpRet |              55 |
# |          MinEpRet |              12 |
# |             EpLen |              26 |
# |      AverageVVals |            19.5 |
# |          StdVVals |            4.95 |
# |          MaxVVals |            29.2 |
# |          MinVVals |            1.98 |
# | TotalEnvInteracts |         3.5e+03 |
# |            LossPi |        -0.00226 |
# |             LossV |            96.8 |
# |       DeltaLossPi |         -0.0131 |
# |        DeltaLossV |           -18.6 |
# |           Entropy |           0.686 |
# |                KL |          0.0104 |
# |          ClipFrac |            0.31 |
# |          StopIter |              79 |
# |              Time |            9.65 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 33 steps.
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            38.9 |
# |          StdEpRet |            13.9 |
# |          MaxEpRet |              69 |
# |          MinEpRet |              14 |
# |             EpLen |            38.9 |
# |      AverageVVals |            17.7 |
# |          StdVVals |            4.88 |
# |          MaxVVals |            24.9 |
# |          MinVVals |             1.5 |
# | TotalEnvInteracts |           4e+03 |
# |            LossPi |         -0.0077 |
# |             LossV |             105 |
# |       DeltaLossPi |        -0.00618 |
# |        DeltaLossV |           -10.5 |
# |           Entropy |           0.682 |
# |                KL |          0.0058 |
# |          ClipFrac |            0.31 |
# |          StopIter |              79 |
# |              Time |              11 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 12 steps.
# Early stopping at step 28 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            24.4 |
# |          StdEpRet |            12.7 |
# |          MaxEpRet |              63 |
# |          MinEpRet |              10 |
# |             EpLen |            24.4 |
# |      AverageVVals |            18.5 |
# |          StdVVals |             5.3 |
# |          MaxVVals |            25.5 |
# |          MinVVals |           -1.49 |
# | TotalEnvInteracts |         4.5e+03 |
# |            LossPi |         -0.0216 |
# |             LossV |            78.1 |
# |       DeltaLossPi |        -0.00826 |
# |        DeltaLossV |             -22 |
# |           Entropy |           0.688 |
# |                KL |          0.0152 |
# |          ClipFrac |           0.278 |
# |          StopIter |              28 |
# |              Time |            12.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 20 steps.
# Early stopping at step 18 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            25.3 |
# |          StdEpRet |            12.6 |
# |          MaxEpRet |              57 |
# |          MinEpRet |              10 |
# |             EpLen |            25.3 |
# |      AverageVVals |            14.7 |
# |          StdVVals |               6 |
# |          MaxVVals |            22.2 |
# |          MinVVals |           -7.84 |
# | TotalEnvInteracts |           5e+03 |
# |            LossPi |          -0.016 |
# |             LossV |            68.6 |
# |       DeltaLossPi |        -0.00927 |
# |        DeltaLossV |           -7.91 |
# |           Entropy |           0.685 |
# |                KL |          0.0152 |
# |          ClipFrac |           0.362 |
# |          StopIter |              18 |
# |              Time |              13 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 14 steps.
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            37.4 |
# |          StdEpRet |            19.5 |
# |          MaxEpRet |              86 |
# |          MinEpRet |              13 |
# |             EpLen |            37.4 |
# |      AverageVVals |            14.3 |
# |          StdVVals |            6.45 |
# |          MaxVVals |            21.4 |
# |          MinVVals |           -14.5 |
# | TotalEnvInteracts |         5.5e+03 |
# |            LossPi |          0.0046 |
# |             LossV |             183 |
# |       DeltaLossPi |         -0.0112 |
# |        DeltaLossV |           -55.7 |
# |           Entropy |           0.681 |
# |                KL |          0.0104 |
# |          ClipFrac |           0.322 |
# |          StopIter |              79 |
# |              Time |            14.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 9 steps.
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            27.3 |
# |          StdEpRet |              14 |
# |          MaxEpRet |              63 |
# |          MinEpRet |              10 |
# |             EpLen |            27.3 |
# |      AverageVVals |            20.5 |
# |          StdVVals |            7.06 |
# |          MaxVVals |              28 |
# |          MinVVals |           -5.54 |
# | TotalEnvInteracts |           6e+03 |
# |            LossPi |        -0.00333 |
# |             LossV |              89 |
# |       DeltaLossPi |         -0.0204 |
# |        DeltaLossV |           -31.2 |
# |           Entropy |           0.679 |
# |                KL |         0.00716 |
# |          ClipFrac |           0.406 |
# |          StopIter |              79 |
# |              Time |            15.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 13 steps.
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            44.3 |
# |          StdEpRet |            25.6 |
# |          MaxEpRet |              92 |
# |          MinEpRet |              17 |
# |             EpLen |            44.3 |
# |      AverageVVals |            16.8 |
# |          StdVVals |            5.27 |
# |          MaxVVals |            23.9 |
# |          MinVVals |           -5.75 |
# | TotalEnvInteracts |         6.5e+03 |
# |            LossPi |         0.00847 |
# |             LossV |             251 |
# |       DeltaLossPi |        -0.00731 |
# |        DeltaLossV |           -75.1 |
# |           Entropy |           0.671 |
# |                KL |        0.000293 |
# |          ClipFrac |            0.37 |
# |          StopIter |              79 |
# |              Time |            16.8 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 48 steps.
# Early stopping at step 0 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            26.6 |
# |          StdEpRet |            21.1 |
# |          MaxEpRet |              96 |
# |          MinEpRet |              10 |
# |             EpLen |            26.6 |
# |      AverageVVals |            24.2 |
# |          StdVVals |            7.91 |
# |          MaxVVals |            34.6 |
# |          MinVVals |           -1.53 |
# | TotalEnvInteracts |           7e+03 |
# |            LossPi |        -0.00904 |
# |             LossV |             172 |
# |       DeltaLossPi |               0 |
# |        DeltaLossV |           -33.4 |
# |           Entropy |           0.683 |
# |                KL |          0.0191 |
# |          ClipFrac |             0.3 |
# |          StopIter |               0 |
# |              Time |            17.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 16 steps.
# Early stopping at step 0 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            24.2 |
# |          StdEpRet |            23.2 |
# |          MaxEpRet |             116 |
# |          MinEpRet |               8 |
# |             EpLen |            24.2 |
# |      AverageVVals |            16.3 |
# |          StdVVals |            8.06 |
# |          MaxVVals |            29.9 |
# |          MinVVals |           -8.78 |
# | TotalEnvInteracts |         7.5e+03 |
# |            LossPi |         -0.0168 |
# |             LossV |             273 |
# |       DeltaLossPi |               0 |
# |        DeltaLossV |           -95.5 |
# |           Entropy |           0.682 |
# |                KL |          0.0173 |
# |          ClipFrac |           0.332 |
# |          StopIter |               0 |
# |              Time |            18.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 40 steps.
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            38.3 |
# |          StdEpRet |            21.9 |
# |          MaxEpRet |              86 |
# |          MinEpRet |              12 |
# |             EpLen |            38.3 |
# |      AverageVVals |            19.5 |
# |          StdVVals |            8.85 |
# |          MaxVVals |            38.8 |
# |          MinVVals |           -13.4 |
# | TotalEnvInteracts |           8e+03 |
# |            LossPi |        -0.00847 |
# |             LossV |             186 |
# |       DeltaLossPi |        -0.00623 |
# |        DeltaLossV |           -53.7 |
# |           Entropy |           0.681 |
# |                KL |         -0.0094 |
# |          ClipFrac |           0.356 |
# |          StopIter |              79 |
# |              Time |            19.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 85 steps.
# Early stopping at step 48 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            29.6 |
# |          StdEpRet |            17.4 |
# |          MaxEpRet |              61 |
# |          MinEpRet |              10 |
# |             EpLen |            29.6 |
# |      AverageVVals |            22.8 |
# |          StdVVals |            7.48 |
# |          MaxVVals |            32.2 |
# |          MinVVals |           -4.01 |
# | TotalEnvInteracts |         8.5e+03 |
# |            LossPi |         -0.0101 |
# |             LossV |             154 |
# |       DeltaLossPi |        -0.00827 |
# |        DeltaLossV |           -16.9 |
# |           Entropy |           0.679 |
# |                KL |          0.0151 |
# |          ClipFrac |           0.382 |
# |          StopIter |              48 |
# |              Time |            20.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 27 steps.
# Early stopping at step 38 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            27.8 |
# |          StdEpRet |              19 |
# |          MaxEpRet |              72 |
# |          MinEpRet |              11 |
# |             EpLen |            27.8 |
# |      AverageVVals |            20.6 |
# |          StdVVals |            8.03 |
# |          MaxVVals |            30.8 |
# |          MinVVals |           -11.7 |
# | TotalEnvInteracts |           9e+03 |
# |            LossPi |         -0.0148 |
# |             LossV |             135 |
# |       DeltaLossPi |         -0.0152 |
# |        DeltaLossV |           -35.1 |
# |           Entropy |           0.682 |
# |                KL |          0.0154 |
# |          ClipFrac |           0.406 |
# |          StopIter |              38 |
# |              Time |            21.8 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 17 steps.
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            40.2 |
# |          StdEpRet |            17.3 |
# |          MaxEpRet |              73 |
# |          MinEpRet |              18 |
# |             EpLen |            40.2 |
# |      AverageVVals |            19.4 |
# |          StdVVals |            7.51 |
# |          MaxVVals |            33.6 |
# |          MinVVals |           -5.53 |
# | TotalEnvInteracts |         9.5e+03 |
# |            LossPi |       -0.000442 |
# |             LossV |             117 |
# |       DeltaLossPi |        -0.00876 |
# |        DeltaLossV |           -14.5 |
# |           Entropy |           0.672 |
# |                KL |         0.00193 |
# |          ClipFrac |           0.432 |
# |          StopIter |              79 |
# |              Time |            23.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 32 steps.
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |              39 |
# |          StdEpRet |            25.1 |
# |          MaxEpRet |             105 |
# |          MinEpRet |              13 |
# |             EpLen |              39 |
# |      AverageVVals |            19.6 |
# |          StdVVals |            6.56 |
# |          MaxVVals |            28.2 |
# |          MinVVals |           -5.23 |
# | TotalEnvInteracts |           1e+04 |
# |            LossPi |         0.00994 |
# |             LossV |             197 |
# |       DeltaLossPi |         -0.0167 |
# |        DeltaLossV |           -42.5 |
# |           Entropy |           0.676 |
# |                KL |          0.0083 |
# |          ClipFrac |           0.386 |
# |          StopIter |              79 |
# |              Time |            24.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 19 steps.
# Warning: could not pickle state_dict.
# Early stopping at step 45 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            68.7 |
# |          StdEpRet |            19.9 |
# |          MaxEpRet |              98 |
# |          MinEpRet |              43 |
# |             EpLen |            68.7 |
# |      AverageVVals |              25 |
# |          StdVVals |            8.65 |
# |          MaxVVals |            35.8 |
# |          MinVVals |           -8.44 |
# | TotalEnvInteracts |        1.05e+04 |
# |            LossPi |          0.0569 |
# |             LossV |             253 |
# |       DeltaLossPi |         -0.0246 |
# |        DeltaLossV |           -94.5 |
# |           Entropy |           0.663 |
# |                KL |          0.0155 |
# |          ClipFrac |           0.426 |
# |          StopIter |              45 |
# |              Time |            25.6 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 30 steps.
# Early stopping at step 21 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            33.6 |
# |          StdEpRet |            20.9 |
# |          MaxEpRet |              80 |
# |          MinEpRet |              10 |
# |             EpLen |            33.6 |
# |      AverageVVals |            28.3 |
# |          StdVVals |            12.9 |
# |          MaxVVals |            39.9 |
# |          MinVVals |           -14.2 |
# | TotalEnvInteracts |         1.1e+04 |
# |            LossPi |           0.044 |
# |             LossV |             206 |
# |       DeltaLossPi |         -0.0437 |
# |        DeltaLossV |             -98 |
# |           Entropy |           0.672 |
# |                KL |          0.0154 |
# |          ClipFrac |           0.706 |
# |          StopIter |              21 |
# |              Time |            26.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 10 steps.
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            44.5 |
# |          StdEpRet |            29.5 |
# |          MaxEpRet |             115 |
# |          MinEpRet |              14 |
# |             EpLen |            44.5 |
# |      AverageVVals |              23 |
# |          StdVVals |            5.64 |
# |          MaxVVals |            28.7 |
# |          MinVVals |            -2.7 |
# | TotalEnvInteracts |        1.15e+04 |
# |            LossPi |        0.000187 |
# |             LossV |             242 |
# |       DeltaLossPi |        -0.00926 |
# |        DeltaLossV |           -41.2 |
# |           Entropy |           0.674 |
# |                KL |        -0.00865 |
# |          ClipFrac |            0.35 |
# |          StopIter |              79 |
# |              Time |            27.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 23 steps.
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            39.8 |
# |          StdEpRet |            30.3 |
# |          MaxEpRet |             129 |
# |          MinEpRet |              16 |
# |             EpLen |            39.8 |
# |      AverageVVals |            20.2 |
# |          StdVVals |            11.7 |
# |          MaxVVals |            34.9 |
# |          MinVVals |           -7.99 |
# | TotalEnvInteracts |         1.2e+04 |
# |            LossPi |          0.0179 |
# |             LossV |             389 |
# |       DeltaLossPi |         -0.0163 |
# |        DeltaLossV |            -136 |
# |           Entropy |           0.672 |
# |                KL |          0.0104 |
# |          ClipFrac |           0.386 |
# |          StopIter |              79 |
# |              Time |            29.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 31 steps.
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            36.1 |
# |          StdEpRet |              19 |
# |          MaxEpRet |              65 |
# |          MinEpRet |               8 |
# |             EpLen |            36.1 |
# |      AverageVVals |            25.1 |
# |          StdVVals |            9.04 |
# |          MaxVVals |            45.3 |
# |          MinVVals |           -5.42 |
# | TotalEnvInteracts |        1.25e+04 |
# |            LossPi |        -0.00217 |
# |             LossV |             184 |
# |       DeltaLossPi |        -0.00923 |
# |        DeltaLossV |           -82.8 |
# |           Entropy |           0.672 |
# |                KL |        0.000922 |
# |          ClipFrac |           0.374 |
# |          StopIter |              79 |
# |              Time |            30.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 69 steps.
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            61.6 |
# |          StdEpRet |            31.2 |
# |          MaxEpRet |             122 |
# |          MinEpRet |              22 |
# |             EpLen |            61.6 |
# |      AverageVVals |            22.1 |
# |          StdVVals |             6.4 |
# |          MaxVVals |            31.6 |
# |          MinVVals |           -7.88 |
# | TotalEnvInteracts |         1.3e+04 |
# |            LossPi |          0.0211 |
# |             LossV |             322 |
# |       DeltaLossPi |         -0.0074 |
# |        DeltaLossV |            -126 |
# |           Entropy |           0.665 |
# |                KL |         -0.0104 |
# |          ClipFrac |           0.362 |
# |          StopIter |              79 |
# |              Time |            31.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 27 steps.
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            52.6 |
# |          StdEpRet |              23 |
# |          MaxEpRet |             100 |
# |          MinEpRet |              13 |
# |             EpLen |            52.6 |
# |      AverageVVals |              31 |
# |          StdVVals |            9.84 |
# |          MaxVVals |            40.9 |
# |          MinVVals |           -9.64 |
# | TotalEnvInteracts |        1.35e+04 |
# |            LossPi |          0.0134 |
# |             LossV |             173 |
# |       DeltaLossPi |        -0.00573 |
# |        DeltaLossV |           -33.9 |
# |           Entropy |           0.661 |
# |                KL |       -0.000512 |
# |          ClipFrac |           0.328 |
# |          StopIter |              79 |
# |              Time |            32.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 38 steps.
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |              66 |
# |          StdEpRet |            43.2 |
# |          MaxEpRet |             140 |
# |          MinEpRet |              25 |
# |             EpLen |              66 |
# |      AverageVVals |              27 |
# |          StdVVals |             8.6 |
# |          MaxVVals |            38.7 |
# |          MinVVals |           -5.79 |
# | TotalEnvInteracts |         1.4e+04 |
# |            LossPi |          0.0274 |
# |             LossV |             434 |
# |       DeltaLossPi |         -0.0173 |
# |        DeltaLossV |           -97.5 |
# |           Entropy |           0.664 |
# |                KL |         -0.0106 |
# |          ClipFrac |            0.38 |
# |          StopIter |              79 |
# |              Time |            34.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 28 steps.
# Early stopping at step 0 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            36.3 |
# |          StdEpRet |            19.3 |
# |          MaxEpRet |              73 |
# |          MinEpRet |              10 |
# |             EpLen |            36.3 |
# |      AverageVVals |              35 |
# |          StdVVals |            11.3 |
# |          MaxVVals |              48 |
# |          MinVVals |           -4.07 |
# | TotalEnvInteracts |        1.45e+04 |
# |            LossPi |          0.0141 |
# |             LossV |             376 |
# |       DeltaLossPi |               0 |
# |        DeltaLossV |            -253 |
# |           Entropy |           0.668 |
# |                KL |          0.0329 |
# |          ClipFrac |           0.314 |
# |          StopIter |               0 |
# |              Time |              35 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 35 steps.
# Early stopping at step 12 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            42.3 |
# |          StdEpRet |            24.6 |
# |          MaxEpRet |              90 |
# |          MinEpRet |              15 |
# |             EpLen |            42.3 |
# |      AverageVVals |            19.8 |
# |          StdVVals |            8.61 |
# |          MaxVVals |            31.8 |
# |          MinVVals |           -8.07 |
# | TotalEnvInteracts |         1.5e+04 |
# |            LossPi |          0.0104 |
# |             LossV |             167 |
# |       DeltaLossPi |        -0.00584 |
# |        DeltaLossV |           -31.1 |
# |           Entropy |           0.663 |
# |                KL |           0.015 |
# |          ClipFrac |           0.328 |
# |          StopIter |              12 |
# |              Time |            35.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 3 steps.
# Warning: could not pickle state_dict.
# Early stopping at step 25 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            49.7 |
# |          StdEpRet |            29.8 |
# |          MaxEpRet |             107 |
# |          MinEpRet |              11 |
# |             EpLen |            49.7 |
# |      AverageVVals |            24.8 |
# |          StdVVals |            9.39 |
# |          MaxVVals |            36.1 |
# |          MinVVals |           -10.8 |
# | TotalEnvInteracts |        1.55e+04 |
# |            LossPi |         -0.0118 |
# |             LossV |             186 |
# |       DeltaLossPi |         -0.0138 |
# |        DeltaLossV |           -19.4 |
# |           Entropy |           0.678 |
# |                KL |          0.0155 |
# |          ClipFrac |            0.41 |
# |          StopIter |              25 |
# |              Time |              37 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 21 steps.
# Early stopping at step 0 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            31.9 |
# |          StdEpRet |            19.2 |
# |          MaxEpRet |              88 |
# |          MinEpRet |               9 |
# |             EpLen |            31.9 |
# |      AverageVVals |            27.2 |
# |          StdVVals |            8.65 |
# |          MaxVVals |            40.5 |
# |          MinVVals |           -1.76 |
# | TotalEnvInteracts |         1.6e+04 |
# |            LossPi |          0.0342 |
# |             LossV |             173 |
# |       DeltaLossPi |               0 |
# |        DeltaLossV |             -69 |
# |           Entropy |           0.649 |
# |                KL |          0.0234 |
# |          ClipFrac |           0.402 |
# |          StopIter |               0 |
# |              Time |            37.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 1 steps.
# Early stopping at step 23 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            41.6 |
# |          StdEpRet |            21.6 |
# |          MaxEpRet |              81 |
# |          MinEpRet |              14 |
# |             EpLen |            41.6 |
# |      AverageVVals |            17.1 |
# |          StdVVals |            10.9 |
# |          MaxVVals |              33 |
# |          MinVVals |           -18.1 |
# | TotalEnvInteracts |        1.65e+04 |
# |            LossPi |          0.0327 |
# |             LossV |             168 |
# |       DeltaLossPi |         -0.0126 |
# |        DeltaLossV |           -52.3 |
# |           Entropy |           0.656 |
# |                KL |           0.016 |
# |          ClipFrac |           0.366 |
# |          StopIter |              23 |
# |              Time |            38.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 36 steps.
# Early stopping at step 1 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |              58 |
# |          StdEpRet |            41.5 |
# |          MaxEpRet |             128 |
# |          MinEpRet |              11 |
# |             EpLen |              58 |
# |      AverageVVals |            19.6 |
# |          StdVVals |            10.5 |
# |          MaxVVals |              35 |
# |          MinVVals |           -5.98 |
# | TotalEnvInteracts |         1.7e+04 |
# |            LossPi |           0.043 |
# |             LossV |             560 |
# |       DeltaLossPi |        0.000149 |
# |        DeltaLossV |            -276 |
# |           Entropy |           0.653 |
# |                KL |          0.0153 |
# |          ClipFrac |           0.324 |
# |          StopIter |               1 |
# |              Time |            39.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 44 steps.
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            65.1 |
# |          StdEpRet |            27.7 |
# |          MaxEpRet |             108 |
# |          MinEpRet |              27 |
# |             EpLen |            65.1 |
# |      AverageVVals |            39.7 |
# |          StdVVals |            7.06 |
# |          MaxVVals |              50 |
# |          MinVVals |            15.9 |
# | TotalEnvInteracts |        1.75e+04 |
# |            LossPi |           0.011 |
# |             LossV |             400 |
# |       DeltaLossPi |         -0.0101 |
# |        DeltaLossV |            -183 |
# |           Entropy |           0.668 |
# |                KL |         -0.0225 |
# |          ClipFrac |           0.342 |
# |          StopIter |              79 |
# |              Time |            41.6 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 21 steps.
# Early stopping at step 0 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            43.5 |
# |          StdEpRet |            23.8 |
# |          MaxEpRet |              97 |
# |          MinEpRet |              15 |
# |             EpLen |            43.5 |
# |      AverageVVals |            34.1 |
# |          StdVVals |            7.17 |
# |          MaxVVals |            41.9 |
# |          MinVVals |           -1.87 |
# | TotalEnvInteracts |         1.8e+04 |
# |            LossPi |         0.00923 |
# |             LossV |             291 |
# |       DeltaLossPi |               0 |
# |        DeltaLossV |            -118 |
# |           Entropy |           0.662 |
# |                KL |          0.0245 |
# |          ClipFrac |           0.326 |
# |          StopIter |               0 |
# |              Time |            42.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 34 steps.
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            51.8 |
# |          StdEpRet |            45.7 |
# |          MaxEpRet |             164 |
# |          MinEpRet |              14 |
# |             EpLen |            51.8 |
# |      AverageVVals |              23 |
# |          StdVVals |            9.21 |
# |          MaxVVals |            33.3 |
# |          MinVVals |           -7.84 |
# | TotalEnvInteracts |        1.85e+04 |
# |            LossPi |         0.00885 |
# |             LossV |             477 |
# |       DeltaLossPi |         -0.0154 |
# |        DeltaLossV |            -149 |
# |           Entropy |           0.665 |
# |                KL |         0.00412 |
# |          ClipFrac |           0.388 |
# |          StopIter |              79 |
# |              Time |            43.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 18 steps.
# Early stopping at step 0 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            48.2 |
# |          StdEpRet |            44.1 |
# |          MaxEpRet |             142 |
# |          MinEpRet |              12 |
# |             EpLen |            48.2 |
# |      AverageVVals |            32.5 |
# |          StdVVals |            11.2 |
# |          MaxVVals |            43.4 |
# |          MinVVals |           -17.1 |
# | TotalEnvInteracts |         1.9e+04 |
# |            LossPi |          0.0124 |
# |             LossV |             373 |
# |       DeltaLossPi |               0 |
# |        DeltaLossV |           -47.2 |
# |           Entropy |           0.654 |
# |                KL |           0.018 |
# |          ClipFrac |           0.336 |
# |          StopIter |               0 |
# |              Time |            44.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 142 steps.
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            51.1 |
# |          StdEpRet |            23.8 |
# |          MaxEpRet |              97 |
# |          MinEpRet |              24 |
# |             EpLen |            51.1 |
# |      AverageVVals |            32.8 |
# |          StdVVals |            10.4 |
# |          MaxVVals |            45.9 |
# |          MinVVals |            -9.3 |
# | TotalEnvInteracts |        1.95e+04 |
# |            LossPi |          0.0369 |
# |             LossV |             501 |
# |       DeltaLossPi |          -0.011 |
# |        DeltaLossV |            -115 |
# |           Entropy |           0.658 |
# |                KL |         0.00331 |
# |          ClipFrac |           0.394 |
# |          StopIter |              79 |
# |              Time |              46 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 32 steps.
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            58.5 |
# |          StdEpRet |            35.4 |
# |          MaxEpRet |             121 |
# |          MinEpRet |              23 |
# |             EpLen |            58.5 |
# |      AverageVVals |              34 |
# |          StdVVals |            14.5 |
# |          MaxVVals |            48.9 |
# |          MinVVals |           -14.8 |
# | TotalEnvInteracts |           2e+04 |
# |            LossPi |          0.0851 |
# |             LossV |             269 |
# |       DeltaLossPi |          -0.031 |
# |        DeltaLossV |           -70.9 |
# |           Entropy |           0.654 |
# |                KL |         0.00367 |
# |          ClipFrac |           0.404 |
# |          StopIter |              79 |
# |              Time |            47.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 1 steps.
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            29.4 |
# |          StdEpRet |              17 |
# |          MaxEpRet |              68 |
# |          MinEpRet |              10 |
# |             EpLen |            29.4 |
# |      AverageVVals |            34.5 |
# |          StdVVals |            12.4 |
# |          MaxVVals |            46.4 |
# |          MinVVals |           -7.36 |
# | TotalEnvInteracts |        2.05e+04 |
# |            LossPi |         0.00513 |
# |             LossV |             417 |
# |       DeltaLossPi |         -0.0147 |
# |        DeltaLossV |            -328 |
# |           Entropy |           0.674 |
# |                KL |         -0.0161 |
# |          ClipFrac |           0.344 |
# |          StopIter |              79 |
# |              Time |            48.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 17 steps.
# Early stopping at step 0 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            30.2 |
# |          StdEpRet |            22.4 |
# |          MaxEpRet |             101 |
# |          MinEpRet |              11 |
# |             EpLen |            30.2 |
# |      AverageVVals |            14.6 |
# |          StdVVals |             9.1 |
# |          MaxVVals |              27 |
# |          MinVVals |           -15.4 |
# | TotalEnvInteracts |         2.1e+04 |
# |            LossPi |        -0.00545 |
# |             LossV |             251 |
# |       DeltaLossPi |               0 |
# |        DeltaLossV |           -68.5 |
# |           Entropy |           0.674 |
# |                KL |          0.0269 |
# |          ClipFrac |           0.366 |
# |          StopIter |               0 |
# |              Time |            49.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 22 steps.
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            29.9 |
# |          StdEpRet |            16.2 |
# |          MaxEpRet |              62 |
# |          MinEpRet |              12 |
# |             EpLen |            29.9 |
# |      AverageVVals |            18.3 |
# |          StdVVals |            10.1 |
# |          MaxVVals |            31.5 |
# |          MinVVals |           -12.6 |
# | TotalEnvInteracts |        2.15e+04 |
# |            LossPi |        -0.00612 |
# |             LossV |             117 |
# |       DeltaLossPi |          -0.014 |
# |        DeltaLossV |           -30.6 |
# |           Entropy |           0.677 |
# |                KL |          0.0092 |
# |          ClipFrac |           0.336 |
# |          StopIter |              79 |
# |              Time |            50.6 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 36 steps.
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |              58 |
# |          StdEpRet |            34.3 |
# |          MaxEpRet |             128 |
# |          MinEpRet |              17 |
# |             EpLen |              58 |
# |      AverageVVals |            15.4 |
# |          StdVVals |            10.2 |
# |          MaxVVals |            26.7 |
# |          MinVVals |           -19.7 |
# | TotalEnvInteracts |         2.2e+04 |
# |            LossPi |          0.0209 |
# |             LossV |             530 |
# |       DeltaLossPi |         -0.0145 |
# |        DeltaLossV |            -279 |
# |           Entropy |           0.668 |
# |                KL |          0.0128 |
# |          ClipFrac |           0.362 |
# |          StopIter |              79 |
# |              Time |            51.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 67 steps.
# Early stopping at step 11 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            36.1 |
# |          StdEpRet |              33 |
# |          MaxEpRet |             140 |
# |          MinEpRet |              15 |
# |             EpLen |            36.1 |
# |      AverageVVals |            31.8 |
# |          StdVVals |            8.21 |
# |          MaxVVals |            41.1 |
# |          MinVVals |            3.97 |
# | TotalEnvInteracts |        2.25e+04 |
# |            LossPi |         0.00525 |
# |             LossV |             353 |
# |       DeltaLossPi |        -0.00247 |
# |        DeltaLossV |           -55.1 |
# |           Entropy |            0.67 |
# |                KL |          0.0152 |
# |          ClipFrac |           0.314 |
# |          StopIter |              11 |
# |              Time |            52.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 26 steps.
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            52.7 |
# |          StdEpRet |            25.5 |
# |          MaxEpRet |             102 |
# |          MinEpRet |              21 |
# |             EpLen |            52.7 |
# |      AverageVVals |            29.1 |
# |          StdVVals |            7.94 |
# |          MaxVVals |            37.8 |
# |          MinVVals |           -12.5 |
# | TotalEnvInteracts |         2.3e+04 |
# |            LossPi |         0.00975 |
# |             LossV |             221 |
# |       DeltaLossPi |        -0.00578 |
# |        DeltaLossV |           -50.3 |
# |           Entropy |           0.668 |
# |                KL |         -0.0108 |
# |          ClipFrac |           0.318 |
# |          StopIter |              79 |
# |              Time |            54.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 43 steps.
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            41.5 |
# |          StdEpRet |            18.2 |
# |          MaxEpRet |              81 |
# |          MinEpRet |              17 |
# |             EpLen |            41.5 |
# |      AverageVVals |            23.8 |
# |          StdVVals |            8.89 |
# |          MaxVVals |            34.6 |
# |          MinVVals |           -7.95 |
# | TotalEnvInteracts |        2.35e+04 |
# |            LossPi |          0.0166 |
# |             LossV |             163 |
# |       DeltaLossPi |         -0.0149 |
# |        DeltaLossV |             -38 |
# |           Entropy |           0.672 |
# |                KL |         0.00262 |
# |          ClipFrac |             0.4 |
# |          StopIter |              79 |
# |              Time |            55.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 16 steps.
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            40.3 |
# |          StdEpRet |            30.5 |
# |          MaxEpRet |             128 |
# |          MinEpRet |              11 |
# |             EpLen |            40.3 |
# |      AverageVVals |            21.7 |
# |          StdVVals |            9.85 |
# |          MaxVVals |            32.5 |
# |          MinVVals |           -9.09 |
# | TotalEnvInteracts |         2.4e+04 |
# |            LossPi |         0.00863 |
# |             LossV |             333 |
# |       DeltaLossPi |         -0.0225 |
# |        DeltaLossV |             -64 |
# |           Entropy |           0.668 |
# |                KL |         0.00778 |
# |          ClipFrac |           0.472 |
# |          StopIter |              79 |
# |              Time |            57.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 31 steps.
# Early stopping at step 0 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |            27.6 |
# |          StdEpRet |            11.8 |
# |          MaxEpRet |              48 |
# |          MinEpRet |              12 |
# |             EpLen |            27.6 |
# |      AverageVVals |            26.2 |
# |          StdVVals |            7.45 |
# |          MaxVVals |            35.3 |
# |          MinVVals |         0.00192 |
# | TotalEnvInteracts |        2.45e+04 |
# |            LossPi |         0.00256 |
# |             LossV |             171 |
# |       DeltaLossPi |               0 |
# |        DeltaLossV |            -125 |
# ...
# |      AverageVVals |              21 |
# |          StdVVals |            9.27 |
# |          MaxVVals |            32.3 |
# |          MinVVals |           -6.23 |
# | TotalEnvInteracts |         4.2e+04 |
# |            LossPi |          0.0101 |
# |             LossV |             522 |
# |       DeltaLossPi |         -0.0112 |
# |        DeltaLossV |            -271 |
# |           Entropy |           0.666 |
# |                KL |         -0.0223 |
# |          ClipFrac |           0.366 |
# |          StopIter |              79 |
# |              Time |            98.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 41 steps.
# Early stopping at step 16 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              84 |
# |      AverageEpRet |            41.7 |
# |          StdEpRet |            31.8 |
# |          MaxEpRet |             113 |
# |          MinEpRet |              10 |
# |             EpLen |            41.7 |
# |      AverageVVals |            37.7 |
# |          StdVVals |            10.2 |
# |          MaxVVals |            48.7 |
# |          MinVVals |            4.12 |
# | TotalEnvInteracts |        4.25e+04 |
# |            LossPi |          0.0256 |
# |             LossV |             350 |
# |       DeltaLossPi |         -0.0149 |
# |        DeltaLossV |            -139 |
# |           Entropy |            0.66 |
# |                KL |          0.0163 |
# |          ClipFrac |           0.346 |
# |          StopIter |              16 |
# |              Time |            99.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 8 steps.
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |            44.7 |
# |          StdEpRet |              23 |
# |          MaxEpRet |              90 |
# |          MinEpRet |              16 |
# |             EpLen |            44.7 |
# |      AverageVVals |            30.2 |
# |          StdVVals |            8.37 |
# |          MaxVVals |            39.3 |
# |          MinVVals |           -3.98 |
# | TotalEnvInteracts |         4.3e+04 |
# |            LossPi |          0.0196 |
# |             LossV |             221 |
# |       DeltaLossPi |         -0.0123 |
# |        DeltaLossV |           -66.3 |
# |           Entropy |           0.659 |
# |                KL |         0.00841 |
# |          ClipFrac |           0.382 |
# |          StopIter |              79 |
# |              Time |             101 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 128 steps.
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |            33.8 |
# |          StdEpRet |            17.6 |
# |          MaxEpRet |              65 |
# |          MinEpRet |              11 |
# |             EpLen |            33.8 |
# |      AverageVVals |            23.1 |
# |          StdVVals |            8.62 |
# |          MaxVVals |              33 |
# |          MinVVals |           -2.56 |
# | TotalEnvInteracts |        4.35e+04 |
# |            LossPi |         0.00859 |
# |             LossV |             241 |
# |       DeltaLossPi |         -0.0125 |
# |        DeltaLossV |           -19.4 |
# |           Entropy |           0.661 |
# |                KL |         0.00977 |
# |          ClipFrac |           0.452 |
# |          StopIter |              79 |
# |              Time |             102 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 65 steps.
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |            62.1 |
# |          StdEpRet |            37.8 |
# |          MaxEpRet |             118 |
# |          MinEpRet |              23 |
# |             EpLen |            62.1 |
# |      AverageVVals |            23.8 |
# |          StdVVals |            9.56 |
# |          MaxVVals |            38.4 |
# |          MinVVals |           -3.48 |
# | TotalEnvInteracts |         4.4e+04 |
# |            LossPi |          0.0583 |
# |             LossV |             358 |
# |       DeltaLossPi |         -0.0286 |
# |        DeltaLossV |            -105 |
# |           Entropy |           0.654 |
# |                KL |         0.00485 |
# |          ClipFrac |            0.42 |
# |          StopIter |              79 |
# |              Time |             103 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 5 steps.
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |            27.5 |
# |          StdEpRet |            13.7 |
# |          MaxEpRet |              59 |
# |          MinEpRet |              14 |
# |             EpLen |            27.5 |
# |      AverageVVals |            33.6 |
# |          StdVVals |            11.8 |
# |          MaxVVals |            48.2 |
# |          MinVVals |           -2.08 |
# | TotalEnvInteracts |        4.45e+04 |
# |            LossPi |         -0.0119 |
# |             LossV |             435 |
# |       DeltaLossPi |         -0.0118 |
# |        DeltaLossV |            -353 |
# |           Entropy |           0.678 |
# |                KL |           0.013 |
# |          ClipFrac |           0.344 |
# |          StopIter |              79 |
# |              Time |             104 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 6 steps.
# Early stopping at step 21 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |            61.8 |
# |          StdEpRet |            41.6 |
# |          MaxEpRet |             139 |
# |          MinEpRet |              19 |
# |             EpLen |            61.8 |
# |      AverageVVals |            15.9 |
# |          StdVVals |            7.73 |
# |          MaxVVals |            26.6 |
# |          MinVVals |            -7.9 |
# | TotalEnvInteracts |         4.5e+04 |
# |            LossPi |          0.0218 |
# |             LossV |             619 |
# |       DeltaLossPi |        -0.00629 |
# |        DeltaLossV |            -296 |
# |           Entropy |           0.661 |
# |                KL |          0.0153 |
# |          ClipFrac |           0.354 |
# |          StopIter |              21 |
# |              Time |             105 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 38 steps.
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |            46.2 |
# |          StdEpRet |            25.6 |
# |          MaxEpRet |              90 |
# |          MinEpRet |              11 |
# |             EpLen |            46.2 |
# |      AverageVVals |            31.4 |
# |          StdVVals |            8.17 |
# |          MaxVVals |            42.9 |
# |          MinVVals |            5.79 |
# | TotalEnvInteracts |        4.55e+04 |
# |            LossPi |          0.0348 |
# |             LossV |             214 |
# |       DeltaLossPi |         -0.0239 |
# |        DeltaLossV |           -70.2 |
# |           Entropy |           0.655 |
# |                KL |         -0.0127 |
# |          ClipFrac |           0.482 |
# |          StopIter |              79 |
# |              Time |             107 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 9 steps.
# Early stopping at step 70 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |            54.6 |
# |          StdEpRet |              39 |
# |          MaxEpRet |             117 |
# |          MinEpRet |              15 |
# |             EpLen |            54.6 |
# |      AverageVVals |            29.4 |
# |          StdVVals |            7.82 |
# |          MaxVVals |            38.4 |
# |          MinVVals |            1.68 |
# | TotalEnvInteracts |         4.6e+04 |
# |            LossPi |          0.0139 |
# |             LossV |             313 |
# |       DeltaLossPi |        -0.00854 |
# |        DeltaLossV |           -37.4 |
# |           Entropy |           0.663 |
# |                KL |           0.015 |
# |          ClipFrac |            0.36 |
# |          StopIter |              70 |
# |              Time |             108 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 88 steps.
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |            51.5 |
# |          StdEpRet |            39.6 |
# |          MaxEpRet |             133 |
# |          MinEpRet |              11 |
# |             EpLen |            51.5 |
# |      AverageVVals |            30.4 |
# |          StdVVals |            8.12 |
# |          MaxVVals |            41.3 |
# |          MinVVals |            0.92 |
# | TotalEnvInteracts |        4.65e+04 |
# |            LossPi |          0.0586 |
# |             LossV |             352 |
# |       DeltaLossPi |         -0.0068 |
# |        DeltaLossV |           -45.4 |
# |           Entropy |           0.649 |
# |                KL |         -0.0134 |
# |          ClipFrac |            0.39 |
# |          StopIter |              79 |
# |              Time |             109 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 5 steps.
# Early stopping at step 16 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |            61.9 |
# |          StdEpRet |            46.7 |
# |          MaxEpRet |             160 |
# |          MinEpRet |              12 |
# |             EpLen |            61.9 |
# |      AverageVVals |            35.7 |
# |          StdVVals |            8.55 |
# |          MaxVVals |            46.2 |
# |          MinVVals |            7.99 |
# | TotalEnvInteracts |         4.7e+04 |
# |            LossPi |          0.0273 |
# |             LossV |             390 |
# |       DeltaLossPi |         -0.0105 |
# |        DeltaLossV |           -31.5 |
# |           Entropy |           0.655 |
# |                KL |          0.0156 |
# |          ClipFrac |           0.352 |
# |          StopIter |              16 |
# |              Time |             110 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 18 steps.
# Early stopping at step 28 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |            53.6 |
# |          StdEpRet |            52.3 |
# |          MaxEpRet |             193 |
# |          MinEpRet |              10 |
# |             EpLen |            53.6 |
# |      AverageVVals |            24.8 |
# |          StdVVals |            16.2 |
# |          MaxVVals |            44.6 |
# |          MinVVals |           -17.8 |
# | TotalEnvInteracts |        4.75e+04 |
# |            LossPi |           0.031 |
# |             LossV |             989 |
# |       DeltaLossPi |         -0.0103 |
# |        DeltaLossV |            -607 |
# |           Entropy |           0.659 |
# |                KL |          0.0151 |
# |          ClipFrac |            0.37 |
# |          StopIter |              28 |
# |              Time |             111 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 15 steps.
# Early stopping at step 6 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |            60.6 |
# |          StdEpRet |            32.3 |
# |          MaxEpRet |             120 |
# |          MinEpRet |              20 |
# |             EpLen |            60.6 |
# |      AverageVVals |            34.7 |
# |          StdVVals |            15.2 |
# |          MaxVVals |            61.7 |
# |          MinVVals |           -5.39 |
# | TotalEnvInteracts |         4.8e+04 |
# |            LossPi |           0.051 |
# |             LossV |             383 |
# |       DeltaLossPi |        -0.00216 |
# |        DeltaLossV |            -136 |
# |           Entropy |           0.657 |
# |                KL |          0.0151 |
# |          ClipFrac |            0.34 |
# |          StopIter |               6 |
# |              Time |             112 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 15 steps.
# Early stopping at step 8 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |            53.9 |
# |          StdEpRet |            42.3 |
# |          MaxEpRet |             140 |
# |          MinEpRet |              17 |
# |             EpLen |            53.9 |
# |      AverageVVals |            34.4 |
# |          StdVVals |            7.96 |
# |          MaxVVals |              49 |
# |          MinVVals |            4.32 |
# | TotalEnvInteracts |        4.85e+04 |
# |            LossPi |          0.0131 |
# |             LossV |             387 |
# |       DeltaLossPi |        -0.00222 |
# |        DeltaLossV |           -54.1 |
# |           Entropy |           0.658 |
# |                KL |          0.0152 |
# |          ClipFrac |            0.35 |
# |          StopIter |               8 |
# |              Time |             113 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 39 steps.
# Early stopping at step 0 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |            46.1 |
# |          StdEpRet |            26.2 |
# |          MaxEpRet |              93 |
# |          MinEpRet |              12 |
# |             EpLen |            46.1 |
# |      AverageVVals |              32 |
# |          StdVVals |             9.5 |
# |          MaxVVals |            43.6 |
# |          MinVVals |           -3.97 |
# | TotalEnvInteracts |         4.9e+04 |
# |            LossPi |         0.00331 |
# |             LossV |             231 |
# |       DeltaLossPi |               0 |
# |        DeltaLossV |           -46.7 |
# |           Entropy |            0.66 |
# |                KL |          0.0152 |
# |          ClipFrac |           0.348 |
# |          StopIter |               0 |
# |              Time |             114 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 5 steps.
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |            61.9 |
# |          StdEpRet |            36.7 |
# |          MaxEpRet |             127 |
# |          MinEpRet |              17 |
# |             EpLen |            61.9 |
# |      AverageVVals |            24.7 |
# |          StdVVals |            13.4 |
# |          MaxVVals |            38.7 |
# |          MinVVals |           -12.9 |
# | TotalEnvInteracts |        4.95e+04 |
# |            LossPi |          0.0319 |
# |             LossV |             421 |
# |       DeltaLossPi |        -0.00924 |
# |        DeltaLossV |            -143 |
# |           Entropy |           0.658 |
# |                KL |         0.00077 |
# |          ClipFrac |           0.366 |
# |          StopIter |              79 |
# |              Time |             115 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 91 steps.
# Warning: could not pickle state_dict.
# Early stopping at step 65 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |            51.1 |
# |          StdEpRet |            44.6 |
# |          MaxEpRet |             155 |
# |          MinEpRet |              15 |
# |             EpLen |            51.1 |
# |      AverageVVals |            29.8 |
# |          StdVVals |            11.5 |
# |          MaxVVals |            44.3 |
# |          MinVVals |           -4.86 |
# | TotalEnvInteracts |           5e+04 |
# |            LossPi |           0.056 |
# |             LossV |             448 |
# |       DeltaLossPi |         -0.0167 |
# |        DeltaLossV |           -94.7 |
# |           Entropy |            0.64 |
# |                KL |           0.015 |
# |          ClipFrac |           0.456 |
# |          StopIter |              65 |
# |              Time |             116 |
# ---------------------------------------

# %%
fin = open('cartpole_ppo_learner.pkl', 'rb')
unpickler = pickle.Unpickler(fin)

# %%
obs, action_dist, action, reward, next_obs, done = unpickler.load()

# %%
obs
# Out:
# array([-0.01171707, -0.03534962, -0.04228413,  0.03623856])

# %%
action_dist
# Out:
# Categorical(probs: torch.Size([2]), logits: torch.Size([2]))

# %%
action
# Out:
# tensor(1)

# %%
reward
# Out:
# 1.0

# %%
next_obs
# Out:
# array([-0.01242406,  0.16035239, -0.04155936, -0.26947989])

# %%
done
# Out:
# False
